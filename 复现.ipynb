# %%
# !nvidia-smi
# Out:
# Fri Feb 13 16:58:33 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# !curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xvj bin/micromamba
# !./bin/micromamba create -y -n bioredirect_py311 -c conda-forge python=3.11 pip
# Out:
# /content
# bin/micromamba
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch     1%[+] 0.2s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    37%[+] 0.3s
# conda-forge/linux-64   4%
# conda-forge/noarch    68%[+] 0.4s
# conda-forge/linux-64  10%
# conda-forge/noarch    87%conda-forge/noarch
# [+] 0.5s
# conda-forge/linux-64  14%[+] 0.6s
# conda-forge/linux-64  22%[+] 0.7s
# conda-forge/linux-64  22%[+] 0.8s
# conda-forge/linux-64  30%[+] 0.9s
# conda-forge/linux-64  41%[+] 1.0s
# conda-forge/linux-64  48%[+] 1.1s
# conda-forge/linux-64  51%[+] 1.2s
# conda-forge/linux-64  54%[+] 1.3s
# conda-forge/linux-64  65%[+] 1.4s
# conda-forge/linux-64  65%[+] 1.5s
# conda-forge/linux-64  65%[+] 1.6s
# conda-forge/linux-64  65%[+] 1.7s
# conda-forge/linux-64  65%[+] 1.8s
# conda-forge/linux-64  65%[+] 1.9s
# conda-forge/linux-64  65%[+] 2.0s
# conda-forge/linux-64  65%[+] 2.1s
# conda-forge/linux-64  66%[+] 2.2s
# conda-forge/linux-64  66%[+] 2.3s
# ...

# %%
# %%bash
# source /content/micromamba/etc/profile.d/micromamba.sh
# micromamba activate bioredirect_py311
#
# python -V
# pip -V
#
# pip -q install -U pip
# pip -q install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126
#
# cd /content
# test -d BioREDirect || git clone https://github.com/ncbi-nlp/BioREDirect.git
# cd /content/BioREDirect
# pip -q install -r requirements.txt
# Out:
# Python 3.12.12
# pip 24.1.2 from /usr/local/lib/python3.12/dist-packages/pip (python 3.12)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 88.7 MB/s eta 0:00:00
# bash: line 1: /content/micromamba/etc/profile.d/micromamba.sh: No such file or directory
# bash: line 2: micromamba: command not found
# Cloning into 'BioREDirect'...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.0 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.31.1 which is incompatible.
# tensorflow 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.31.1 which is incompatible.
# ...

# %%
# %%bash
# source /content/micromamba/etc/profile.d/micromamba.sh
# micromamba activate bioredirect_py311
# python - <<'PY'
# import torch
# print("cuda:", torch.cuda.is_available())
# PY
# Out:
# cuda: True
# bash: line 1: /content/micromamba/etc/profile.d/micromamba.sh: No such file or directory
# bash: line 2: micromamba: command not found

# %%
# %cd /content
# !rm -rf /content/micromamba /content/bin
# !mkdir -p /content/micromamba /content/bin
# !curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xvj -C /content/bin --strip-components=1 bin/micromamba
# !/content/bin/micromamba --version

# !/content/bin/micromamba create -y -p /content/micromamba/env -c conda-forge python=3.11 pip
# Out:
# /content
# bin/micromamba
# 2.5.0
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
#
#
# Transaction
#
#   Prefix: /content/micromamba/env
#
#   Updating specs:
#
#    - python=3.11
#    - pip
#
#
#   Package              Version  Build                 Channel           Size
# ──────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────
#
#   + _openmp_mutex          4.5  20_gnu                conda-forge     Cached
#   + bzip2                1.0.8  hda65f42_8            conda-forge     Cached
#   + ca-certificates   2026.1.4  hbd8a1cb_0            conda-forge     Cached
#   + icu                   78.2  h33c6efd_0            conda-forge     Cached
#   + ld_impl_linux-64    2.45.1  default_hbd61a6d_101  conda-forge     Cached
# ...

# %%
# %%bash
# set -e
# /content/micromamba/env/bin/python -V
# /content/micromamba/env/bin/pip -V
#
# /content/micromamba/env/bin/pip -q install -U pip
# /content/micromamba/env/bin/pip -q install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126
#
# cd /content
# test -d BioREDirect || git clone https://github.com/ncbi-nlp/BioREDirect.git
# cd /content/BioREDirect
#
# /content/micromamba/env/bin/pip -q install -r requirements.txt
#
# /content/micromamba/env/bin/python - <<'PY'
# import torch
# print("torch:", torch.__version__)
# print("cuda:", torch.cuda.is_available())
# print("gpu:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else None)
# PY
# Out:
# Python 3.11.14
# pip 26.0.1 from /content/micromamba/env/lib/python3.11/site-packages/pip (python 3.11)
# torch: 2.10.0+cu126
# cuda: True
# gpu: Tesla T4
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /packages/43/e3/7d92a15f894aa0c9c4b49b8ee9ac9850d6e63b03c9c32c0367a13ae62209/mpmath-1.3.0-py3-none-any.whl.metadata

# %%
# %%bash
# set -e
# cd /content/BioREDirect
#
# mkdir -p datasets
#
# # 1) datasets
# wget -q -O datasets.zip https://ftp.ncbi.nlm.nih.gov/pub/lu/BioREDirect/datasets.zip
# unzip -q datasets.zip -d datasets
# rm datasets.zip
#
# # 2) BioLinkBERT 底座
# wget -q -O biorex_biolinkbert_pt.zip https://ftp.ncbi.nlm.nih.gov/pub/lu/BioREx/biorex_biolinkbert_pt.zip
# unzip -q biorex_biolinkbert_pt.zip -d biorex_biolinkbert_pt
# rm biorex_biolinkbert_pt.zip
#
# # 3) BioREDirect 预训练（推理/初始化用）
# wget -q -O bioredirect_biored_pt.zip https://ftp.ncbi.nlm.nih.gov/pub/lu/BioREDirect/bioredirect_biored_pt.zip
# unzip -q bioredirect_biored_pt.zip -d bioredirect_biored_pt
# rm bioredirect_biored_pt.zip
#
# # quick check
# ls -lah bioredirect_biored_pt | head -n 15
# Out:
# total 834M
# drwxr-xr-x 2 root root 4.0K Feb 13 17:09 .
# drwxr-xr-x 8 root root 4.0K Feb 13 17:09 ..
# -rw-r--r-- 1 root root 1.4K Jan 19  2025 added_tokens.json
# -rw-r--r-- 1 root root 3.0K Jan 19  2025 config.json
# -rw-r--r-- 1 root root 414M Jan 19  2025 model.safetensors
# -rw-r--r-- 1 root root 421M Jan 19  2025 out_bioredirect_model.pth
# -rw-r--r-- 1 root root 7.8K Jan 19  2025 special_tokens_map.json
# -rw-r--r-- 1 root root  11K Jan 19  2025 tokenizer_config.json
# -rw-r--r-- 1 root root 249K Jan 19  2025 vocab.txt

# %%
# %%bash
# set -e
# cd /content/BioREDirect
# bash scripts/run_test_pred.sh
#
# # 生成文件检查
# ls -lah pred_test.pubtator
# ls -lah datasets/bioredirect/bioredirect_bc8_test.pubtator.tsv | head
# ls -lah datasets/bioredirect/bioredirect_bc8_test.pubtator.pred.tsv | head
# Out:
# Process is terminated.

# %%
# %%bash
# set -e
# cd /content/BioREDirect
# bash scripts/run_test_pred.sh
#
# # 生成文件检查
# ls -lah pred_test.pubtator
# ls -lah datasets/bioredirect/bioredirect_bc8_test.pubtator.tsv | head
# ls -lah datasets/bioredirect/bioredirect_bc8_test.pubtator.pred.tsv | head
# Out:
# Converting test pubtator to tsv
# Running test prediction
# ================>args.no_eval False
# Loading model on device: cuda
# Test: P / R / P+N / R+N / R+D / All / Relaxed R / Relaxed R+N / Relaxed R+D / Relaxed All
# Test TP: 4660.0 / 3491.0 / 3496.0 / 2611.0 / 3024.0 / 2281.0 / 4165.0 / 3124.0 / 3124.0 / 3124.0
# Test FP: 1605.0 / 2774.0 / 2769.0 / 3654.0 / 3241.0 / 3984.0 / 2100.0 / 3141.0 / 3141.0 / 3141.0
# Test FN: 1358.0 / 2527.0 / 2522.0 / 3407.0 / 2994.0 / 3737.0 / 1853.0 / 2894.0 / 2894.0 / 2894.0
# Test Precision: 0.7438148443735035 / 0.5572226656025538 / 0.5580207501995211 / 0.41675977653631285 / 0.48268156424581005 / 0.36408619313647245 / 0.664804469273743 / 0.49864325618515565 / 0.49864325618515565 / 0.49864325618515565
# Test Recall: 0.7743436357593885 / 0.5800930541708209 / 0.5809238949817215 / 0.43386507145230974 / 0.5024925224327019 / 0.37902957793286807 / 0.692090395480226 / 0.5191093386507145 / 0.5191093386507145 / 0.5191093386507145
# ...

# %%
# %%bash
# set -e
# mkdir -p /content/drive/MyDrive/bioredirect_runs/pred_only
# cp -v /content/BioREDirect/pred_test.pubtator /content/drive/MyDrive/bioredirect_runs/pred_only/
# cp -v /content/BioREDirect/datasets/bioredirect/bioredirect_bc8_test.pubtator.pred.tsv /content/drive/MyDrive/bioredirect_runs/pred_only/
# Out:
# '/content/BioREDirect/pred_test.pubtator' -> '/content/drive/MyDrive/bioredirect_runs/pred_only/pred_test.pubtator'
# '/content/BioREDirect/datasets/bioredirect/bioredirect_bc8_test.pubtator.pred.tsv' -> '/content/drive/MyDrive/bioredirect_runs/pred_only/bioredirect_bc8_test.pubtator.pred.tsv'

# %%
# %%bash
# set -e
# export PATH="/content/micromamba/env/bin:$PATH"
# cd /content/BioREDirect
#
# bash scripts/run_biored_bc8_exp.sh
# Out:
# ================>args.no_eval False
# Traceback (most recent call last):
#   File "/content/BioREDirect/src/run_exp.py", line 388, in <module>
#     run_train(in_bert_model         = in_bert_model,
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/BioREDirect/src/run_exp.py", line 95, in run_train
#     tokenizer = load_tokenizer(in_bert_model, dataset_processor)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/BioREDirect/src/run_exp.py", line 60, in load_tokenizer
#     tokenizer = BertTokenizer.from_pretrained(in_bert_model)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/micromamba/env/lib/python3.11/site-packages/transformers/tokenization_utils_base.py", line 2069, in from_pretrained
#     return cls._from_pretrained(
#            ^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# %%bash
# set -e
# cd /content/BioREDirect
#
# echo "=== find vocab.txt ==="
# find biorex_biolinkbert_pt -maxdepth 4 -name "vocab.txt" -print
#
# echo "=== find tokenizer_config.json ==="
# find biorex_biolinkbert_pt -maxdepth 4 -name "tokenizer_config.json" -print
#
# echo "=== find config.json ==="
# find biorex_biolinkbert_pt -maxdepth 4 -name "config.json" -print | head
# Out:
# === find vocab.txt ===
# biorex_biolinkbert_pt/biorex_biolinkbert_pt/vocab.txt
# === find tokenizer_config.json ===
# biorex_biolinkbert_pt/biorex_biolinkbert_pt/tokenizer_config.json
# === find config.json ===
# biorex_biolinkbert_pt/biorex_biolinkbert_pt/config.json

# %%
# !grep -nE "bert|model|tokenizer|biolink|biorex" /content/BioREDirect/scripts/run_biored_bc8_exp.sh | head -n 80
# Out:
# 6:    --in_bert_model biorex_biolinkbert_pt \
# 7:    --out_bioredirect_model "out_bioredirect_biored_model" \

# %%
# %%bash
# set -e
# cd /content/BioREDirect
#
# # 把参数里的模型路径改成两层目录
# sed -i 's|--in_bert_model biorex_biolinkbert_pt|--in_bert_model biorex_biolinkbert_pt/biorex_biolinkbert_pt|g' scripts/run_biored_bc8_exp.sh
#
# # 验证
# grep -n "in_bert_model" scripts/run_biored_bc8_exp.sh
# Out:
# 6:    --in_bert_model biorex_biolinkbert_pt/biorex_biolinkbert_pt \

# %%
# !nvidia-smi
# Out:
# Fri Feb 13 18:34:50 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pwd
# !ls -lah
# Out:
# /content
# total 16K
# drwxr-xr-x 1 root root 4.0K Feb  6 14:31 .
# drwxr-xr-x 1 root root 4.0K Feb 13 18:53 ..
# drwxr-xr-x 4 root root 4.0K Feb  6 14:31 .config
# drwxr-xr-x 1 root root 4.0K Feb  6 14:31 sample_data

# %%
# !nvidia-smi
# Out:
# Fri Feb 13 19:18:21 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0             48W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
# !ls -lah /content | head
# !ls -lah /content/BioREDirect 2>/dev/null || echo "BioREDirect not found"
# Out:
# total 16K
# drwxr-xr-x 1 root root 4.0K Feb  6 14:31 .
# drwxr-xr-x 1 root root 4.0K Feb 13 18:53 ..
# drwxr-xr-x 4 root root 4.0K Feb  6 14:31 .config
# drwxr-xr-x 1 root root 4.0K Feb  6 14:31 sample_data
# BioREDirect not found

# %%
# %cd /content
# !git clone https://github.com/ncbi-nlp/BioREDirect.git

# !rm -rf /content/micromamba /content/bin
# !mkdir -p /content/micromamba /content/bin
# !curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xvj -C /content/bin --strip-components=1 bin/micromamba

# !/content/bin/micromamba create -y -p /content/micromamba/env -c conda-forge python=3.11 pip
# Out:
# /content
# Cloning into 'BioREDirect'...
# remote: Enumerating objects: 112, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 112 (delta 66), reused 74 (delta 37), pack-reused 0 (from 0)
# Receiving objects: 100% (112/112), 77.86 KiB | 19.47 MiB/s, done.
# Resolving deltas: 100% (66/66), done.
# bin/micromamba
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch     1%[+] 0.2s
# conda-forge/linux-64   8%
# conda-forge/noarch    35%[+] 0.3s
# conda-forge/linux-64  20%
# conda-forge/noarch    59%[+] 0.4s
# conda-forge/linux-64  32%
# conda-forge/noarch    85%[+] 0.5s
# conda-forge/linux-64  38%
# conda-forge/noarch    98%conda-forge/noarch
# [+] 0.6s
# conda-forge/linux-64  52%[+] 0.7s
# conda-forge/linux-64  75%[+] 0.8s
# conda-forge/linux-64  99%[+] 0.9s
# conda-forge/linux-64  99%conda-forge/linux-64
#
#
# Transaction
#
#   Prefix: /content/micromamba/env
#
#   Updating specs:
#
# ...

# %%
# %%bash
# set -e
#
# /content/micromamba/env/bin/pip install -U pip
# /content/micromamba/env/bin/pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126
#
# cd /content/BioREDirect
# /content/micromamba/env/bin/pip install -r requirements.txt
# Out:
# ...
# Looking in indexes: https://download.pytorch.org/whl/cu126
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 221.1 MB/s  0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 315.9 MB/s  0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 259.2 MB/s  0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 403.5 MB/s  0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 220.1 MB/s  0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 240.7 MB/s  0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 264.8 MB/s  0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 253.3 MB/s  0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 258.0 MB/s  0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 373.3 MB/s  0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 275.6 MB/s  0:00:01
# ...

# %%
# %%bash
# set -e
# cd /content/BioREDirect
#
# mkdir -p datasets
#
# wget -q -O datasets.zip https://ftp.ncbi.nlm.nih.gov/pub/lu/BioREDirect/datasets.zip
# unzip -q datasets.zip -d datasets
# rm datasets.zip
#
# wget -q -O biorex_biolinkbert_pt.zip https://ftp.ncbi.nlm.nih.gov/pub/lu/BioREx/biorex_biolinkbert_pt.zip
# unzip -q biorex_biolinkbert_pt.zip -d biorex_biolinkbert_pt
# rm biorex_biolinkbert_pt.zip
#
# wget -q -O bioredirect_biored_pt.zip https://ftp.ncbi.nlm.nih.gov/pub/lu/BioREDirect/bioredirect_biored_pt.zip
# unzip -q bioredirect_biored_pt.zip -d bioredirect_biored_pt
# rm bioredirect_biored_pt.zip

# %%
# %%bash
# cd /content/BioREDirect
# sed -i 's|--in_bert_model biorex_biolinkbert_pt|--in_bert_model biorex_biolinkbert_pt/biorex_biolinkbert_pt|g' scripts/run_biored_bc8_exp.sh

# %%
# %%bash
# set -e
# export PATH="/content/micromamba/env/bin:$PATH"
# cd /content/BioREDirect
# bash scripts/run_biored_bc8_exp.sh
# Out:
# ================>args.no_eval False
# Epoch 1, Train Loss: 0.8265725885112696
# Epoch 1, Validation TP: 888.0 / 712.0 / 737.0 / 585.0 / 622.0 / 523.0 / 767.0 / 631.0 / 631.0 / 631.0
# Epoch 1, Validation FP: 243.0 / 419.0 / 394.0 / 546.0 / 509.0 / 608.0 / 364.0 / 500.0 / 500.0 / 500.0
# Epoch 1, Validation FN: 275.0 / 451.0 / 426.0 / 578.0 / 541.0 / 640.0 / 396.0 / 532.0 / 532.0 / 532.0
# Epoch 1, Validation Precision: 0.7851458885941645 / 0.6295313881520778 / 0.6516357206012379 / 0.5172413793103449 / 0.5499557913351016 / 0.4624226348364279 / 0.6781609195402298 / 0.5579133510167993 / 0.5579133510167993 / 0.5579133510167993
# Epoch 1, Validation Recall: 0.763542562338779 / 0.6122098022355976 / 0.6337059329320722 / 0.5030094582975064 / 0.5348237317282889 / 0.44969905417024936 / 0.6595012897678418 / 0.5425623387790198 / 0.5425623387790198 / 0.5425623387790198
# ...
